# %%
from __future__ import absolute_import, division, print_function, unicode_literals, unicode_literals

import pathlib
from openpyxl import Workbook  
import openpyxl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import xlrd
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import LeakyReLU
print(tf.__version__)
# Out:
# 2.0.0

# %%
emp1=pd.ExcelFile(r'C:\Users\LG\Anaconda3\envs\tensor\데이터\real_min.xlsx')
real=emp1.parse('Sheet1' , index = False)

# %%
emp2=pd.ExcelFile(r'C:\Users\LG\Anaconda3\envs\tensor\데이터\proposed_min.xlsx')
proposed=emp2.parse('Sheet1' , index = False)

# %%
emp3=pd.ExcelFile(r'C:\Users\LG\Anaconda3\envs\tensor\데이터\DecisionTreeRegressor_min.xlsx')
DecisionTreeRegressor=emp3.parse('Sheet1' , index = False)

# %%
emp4=pd.ExcelFile(r'C:\Users\LG\Anaconda3\envs\tensor\데이터\KNeighborsRegressor_min.xlsx')
KNeighborsRegressor=emp4.parse('Sheet1' , index = False)

# %%
emp5=pd.ExcelFile(r'C:\Users\LG\Anaconda3\envs\tensor\데이터\LinearRegression_min.xlsx')
LinearRegression=emp5.parse('Sheet1' , index = False)

# %%
emp6=pd.ExcelFile(r'C:\Users\LG\Anaconda3\envs\tensor\데이터\RandomForestRegressor_min.xlsx')
RandomForestRegressor=emp6.parse('Sheet1' , index = False)

# %%
plt.figure(figsize=(7,7))
plt.scatter(real, proposed)
plt.xlabel('True Values [Frequency]')
plt.ylabel('Predictions [Frequency]')
plt.axis('equal')
plt.axis('square')
plt.xlim([59.4,59.8])
plt.ylim([59.4,59.8])
_ = plt.plot([59, 60], [59, 60])

# %%
plt.figure(figsize=(7,7))
plt.scatter(real,DecisionTreeRegressor )
plt.xlabel('True Values [Frequency]')
plt.ylabel('Predictions [Frequency]')
plt.axis('equal')
plt.axis('square')
plt.xlim([59.4,59.8])
plt.ylim([59.4,59.8])
_ = plt.plot([59, 60], [59, 60])

# %%
plt.figure(figsize=(7,7))
plt.scatter(real, KNeighborsRegressor )
plt.xlabel('True Values [Frequency]')
plt.ylabel('Predictions [Frequency]')
plt.axis('equal')
plt.axis('square')
plt.xlim([59.4,59.8])
plt.ylim([59.4,59.8])
_ = plt.plot([59, 60], [59, 60])

# %%
plt.figure(figsize=(7,7))
plt.scatter(real, LinearRegression)
plt.xlabel('True Values [Frequency]')
plt.ylabel('Predictions [Frequency]')
plt.axis('equal')
plt.axis('square')
plt.xlim([59.4,59.8])
plt.ylim([59.4,59.8])
_ = plt.plot([59, 60], [59, 60])

# %%
plt.figure(figsize=(7,7))
plt.scatter(real, RandomForestRegressor)
plt.xlabel('True Values [Frequency]')
plt.ylabel('Predictions [Frequency]')
plt.axis('equal')
plt.axis('square')
plt.xlim([59.4,59.8])
plt.ylim([59.4,59.8])
_ = plt.plot([59, 60], [59, 60])
